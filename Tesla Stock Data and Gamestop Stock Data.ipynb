# %%
# use yfinance to extract stock data

import yfinance as yf
tesla = yf.Ticker("TSLA")
# Reset the index, save and displaythe first five rows of the tesla_data dataframe.
tesla_data = tesla.history(period="max")
tesla_data.reset_index(inplace=True)
# to display the dataframe
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
#using webscraping to extract tesla revenue data

tesla_revenue = tesla.history(period="max")
tesla_revenue.reset_index(inplace=True)
tesla_revenue.tail()
# Out:
#                           Date        Open        High         Low  \
# 3471 2024-04-15 00:00:00-04:00  170.240005  170.690002  161.380005
# 3472 2024-04-16 00:00:00-04:00  156.740005  158.190002  153.750000
# 3473 2024-04-17 00:00:00-04:00  157.639999  158.330002  153.779999
# 3474 2024-04-18 00:00:00-04:00  151.250000  152.199997  148.699997
# 3475 2024-04-19 00:00:00-04:00  148.970001  150.940002  146.220001
#
#            Close     Volume  Dividends  Stock Splits
# 3471  161.479996  100245300        0.0           0.0
# 3472  157.110001   97000000        0.0           0.0
# 3473  155.449997   82439700        0.0           0.0
# 3474  149.929993   96098800        0.0           0.0
# 3475  147.050003   86005100        0.0           0.0

# %%
# using yfinance to extract gme stock data

gme = yf.Ticker("gme")
gme_data = gme.history(period="max")
gme_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620129  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716073  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
# using webcraping to extract gme revenue data

# !pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

gme_revenue = gme.history(period="max")
gme_revenue.reset_index(inplace=True)
gme_revenue.tail()
# Out:
# ...
#                           Date   Open   High    Low  Close   Volume  \
# 5579 2024-04-15 00:00:00-04:00  10.81  10.84  10.06  10.06  5086300
# 5580 2024-04-16 00:00:00-04:00  10.00  10.55   9.95  10.37  4162100
# 5581 2024-04-17 00:00:00-04:00  10.44  10.59  10.30  10.30  2096700
# 5582 2024-04-18 00:00:00-04:00  10.32  10.63  10.27  10.31  2175400
# 5583 2024-04-19 00:00:00-04:00  10.20  10.50  10.20  10.42  2455100
#
#       Dividends  Stock Splits
# 5579        0.0           0.0
# 5580        0.0           0.0
# 5581        0.0           0.0
# 5582        0.0           0.0
# 5583        0.0           0.0

# %%
# using webscraping to extract tesla stock revenue data

url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

tesla_revenue = tesla.history(period="max")
tesla_revenue.reset_index(inplace=True)
tesla_revenue.tail()
# Out:
#                           Date        Open        High         Low  \
# 3471 2024-04-15 00:00:00-04:00  170.240005  170.690002  161.380005
# 3472 2024-04-16 00:00:00-04:00  156.740005  158.190002  153.750000
# 3473 2024-04-17 00:00:00-04:00  157.639999  158.330002  153.779999
# 3474 2024-04-18 00:00:00-04:00  151.250000  152.199997  148.699997
# 3475 2024-04-19 00:00:00-04:00  148.970001  150.940002  146.220001
#
#            Close     Volume  Dividends  Stock Splits
# 3471  161.479996  100245300        0.0           0.0
# 3472  157.110001   97000000        0.0           0.0
# 3473  155.449997   82439700        0.0           0.0
# 3474  149.929993   96098800        0.0           0.0
# 3475  147.050003   86005100        0.0           0.0

# %%
# !pip install pandas matplotlib yfinance
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
ticker = 'TSLA'
data = yf.download(ticker, start='2022-01-01', end='2023-01-01')
plt.figure(figsize=(12, 6))
plt.plot(data['Close'])
plt.title('Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# Get GameStop stock data
gme = yf.Ticker("GME")
df = gme.history(period="1y")
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Close'], label='Close Price')
plt.title('GameStop Stock Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid()
plt.show()
